# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
shark_final = pd.read_csv("shark_df.csv")

# %%
shark_final = shark_final.dropna(how='all')

# %%
shark_final.dropna(axis=1, how='all')
# Out:
#       Unnamed: 0         Date    Year        Type             Country  \
# 0              0  25-Jun-2018  2018.0        Boat                 USA
# 1              1  18-Jun-2018  2018.0  Unprovoked                 USA
# 2              2  09-Jun-2018  2018.0     Invalid                 USA
# 3              3  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4              4  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297        6297  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298        6298  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299        6299    1900-1905     0.0  Unprovoked                 USA
# 6300        6300    1883-1889     0.0  Unprovoked              PANAMA
# 6301        6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
shark_final.dropna(axis=0, how='all')
# Out:
#       Unnamed: 0         Date    Year        Type             Country  \
# 0              0  25-Jun-2018  2018.0        Boat                 USA
# 1              1  18-Jun-2018  2018.0  Unprovoked                 USA
# 2              2  09-Jun-2018  2018.0     Invalid                 USA
# 3              3  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4              4  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297        6297  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298        6298  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299        6299    1900-1905     0.0  Unprovoked                 USA
# 6300        6300    1883-1889     0.0  Unprovoked              PANAMA
# 6301        6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
shark_final = shark_final.drop(columns=["Unnamed: 22", "Unnamed: 23"])

# %%
shark_final.fillna("Not specified")
# Out:
#       Unnamed: 0         Date    Year        Type             Country  \
# 0              0  25-Jun-2018  2018.0        Boat                 USA
# 1              1  18-Jun-2018  2018.0  Unprovoked                 USA
# 2              2  09-Jun-2018  2018.0     Invalid                 USA
# 3              3  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4              4  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297        6297  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298        6298  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299        6299    1900-1905     0.0  Unprovoked                 USA
# 6300        6300    1883-1889     0.0  Unprovoked              PANAMA
# 6301        6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location       Activity  \
# ...

# %%
shark_final["Sex "] = shark_final["Sex "].replace(["M ", "N"], "M")

# %%
shark_final["Sex "] = shark_final["Sex "].replace(["lli", "."], "Not specified")

# %%
shark_final["Sex "].unique()
# Out:
# array(['F', 'M', 'Not specified'], dtype=object)

# %%
shark_final.Year.unique()
# Out:
# array([2018., 2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
# ...

# %% [markdown]
# # Hipótesis

# %% [markdown]
# # Primera hipótesis

# %%
# Más que una hipótesis lo que quiero es averiguar qué paises tienen más de 100 ataques registrados

# %%
attacks_per_country = pd.read_csv("attacks_per_country.csv")

# %%
attacks_per_country
# Out:
#                  Unnamed: 0  Country
# 0                       USA     2229
# 1                 AUSTRALIA     1338
# 2              SOUTH AFRICA      579
# 3          PAPUA NEW GUINEA      134
# 4               NEW ZEALAND      128
# ..                      ...      ...
# 207         MALDIVE ISLANDS        1
# 208              NICARAGUA         1
# 209               NORTH SEA        1
# 210  RED SEA / INDIAN OCEAN        1
# 211      CEYLON (SRI LANKA)        1
#
# [212 rows x 2 columns]

# %%
plus_hundred_attacks = attacks_per_country[attacks_per_country.Country > 100]

# %%
plus_hundred_attacks
# Out:
#          Unnamed: 0  Country
# 0               USA     2229
# 1         AUSTRALIA     1338
# 2      SOUTH AFRICA      579
# 3  PAPUA NEW GUINEA      134
# 4       NEW ZEALAND      128
# 5            BRAZIL      112
# 6           BAHAMAS      109

# %%
attacks_per_type = pd.read_csv("attacks_per_type.csv")

# %%
attacks_per_type
# Out:
#      Unnamed: 0  Type
# 0    Unprovoked  4595
# 1      Provoked   574
# 2       Invalid   547
# 3          Boat   341
# 4  Sea Disaster   239
# 5  Questionable     2

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.barplot(x="Unnamed: 0", y="Country", data=plus_hundred_attacks, palette="magma")
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Country'>

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.kdeplot(x=plus_hundred_attacks.Country, hue=plus_hundred_attacks.count)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Density'>

# %%
sns.kdeplot(x=titanic.Age, hue=titanic.Pclass, fill=True);

# %%
## Así es, las costas del pacífico concentran mayor número de accidentes.

# %% [markdown]
# # Segunda hipótesis

# %%
## Mi segunda hipótesis es que los hombres sufrimos más ataques de tiburón que las mujeres.
## ¿Seran los chicos más inconscientes? ¿O es mala suerte?

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(x=shark_final.Type, hue=shark_final["Sex "])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
## Efectivamente, los hombres sufren más ataques con los datos que tenemos.
## Por algo dicen que los hombres viven menos tiempo que las mujeres...

# %%
shark_final.Country.value_counts() > 100
# Out:
# USA                        True
# AUSTRALIA                  True
# SOUTH AFRICA               True
# PAPUA NEW GUINEA           True
# NEW ZEALAND                True
#                           ...
# MALDIVE ISLANDS           False
# NICARAGUA                 False
# NORTH SEA                 False
# RED SEA / INDIAN OCEAN    False
# CEYLON (SRI LANKA)        False
# Name: Country, Length: 212, dtype: bool

# %%
dff = shark_final[shark_final.Country.map(shark_final.Country.value_counts()) > 100]

# %%
dff.head(2)
# Out:
#    Unnamed: 0         Date    Year        Type Country        Area  \
# 0           0  25-Jun-2018  2018.0        Boat     USA  California
# 1           1  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  57
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  11
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
#
#             Time     Species           Investigator or Source  \
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com
#
#                       pdf
# 0    2018.06.25-Wolfe.pdf
# 1  2018.06.18-McNeely.pdf

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.scatterplot(x="Country", y="Type", data=dff, hue="Sex ")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Type'>

# %%
sns.countplot(x=shark_final.Type, hue=shark_final["Sex "])

# %% [markdown]
# # Tercera hipótesis

# %%
## Mi tercera hipótesis se basa en que a medida que pasan los años existen más ataques de tiburón.
## Esto, según creo, se debe a que disponemos de más datos a medida que pasa el tiempo.

# %%
reliable_years = shark_final[shark_final.Year > 1750]

# %%
reliable_years
# Out:
#       Unnamed: 0                  Date    Year        Type            Country  \
# 0              0           25-Jun-2018  2018.0        Boat                USA
# 1              1           18-Jun-2018  2018.0  Unprovoked                USA
# 2              2           09-Jun-2018  2018.0     Invalid                USA
# 3              3           08-Jun-2018  2018.0  Unprovoked          AUSTRALIA
# 4              4           04-Jun-2018  2018.0    Provoked             MEXICO
# ...          ...                   ...     ...         ...                ...
# 6148        6148                  1764  1764.0  Unprovoked              SPAIN
# 6149        6149                  1758  1758.0  Unprovoked  MEDITERRANEAN SEA
# 6150        6150  Reported 27-Oct-1753  1753.0  Unprovoked            JAMAICA
# 6151        6151           27-Jul-1751  1751.0  Unprovoked                USA
# 6153        6153                  1755  1755.0  Unprovoked             SWEDEN
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.histplot(x=reliable_years.Year,kde=True)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
## en efecto estoy en lo cierto

# %%
reliable_years2 = shark_final[shark_final.Year > 1994]

# %%
reliable_years = shark_final[shark_final.Year > 1750]

# %%
fig, ax = plt.subplots(figsize=(18,8))
sns.countplot(x=reliable_years2.Year, hue=reliable_years2["Sex "])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
reliable_years.Type.value_counts()
# Out:
# Unprovoked      4464
# Provoked         567
# Invalid          542
# Boat             339
# Sea Disaster     233
# Questionable       2
# Name: Type, dtype: int64
