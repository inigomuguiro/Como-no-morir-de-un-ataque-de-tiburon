# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
shark_df = pd.read_csv("shark_df")

# %%
shark_df
# Out:
#        Unnamed: 0         Date    Year        Type    Country  \
# 0               0  25-Jun-2018  2018.0        Boat        USA
# 1               1  18-Jun-2018  2018.0  Unprovoked        USA
# 2               2  09-Jun-2018  2018.0     Invalid        USA
# 3               3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4               4  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718       25718          NaN     NaN         NaN        NaN
# 25719       25719          NaN     NaN         NaN        NaN
# 25720       25720          NaN     NaN         NaN        NaN
# 25721       25721          NaN     NaN         NaN        NaN
# 25722       25722          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...
